# %% [markdown]
# <img style="float: left; padding-right: 20px; width: 70px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/84/Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg/1920px-Escudo_de_la_Pontificia_Universidad_Cat%C3%B3lica_de_Chile.svg.png">
#
# **Pontificia Universidad Católica de Chile**<br>
# **Semestre 2021-2**<br>
# **Profesora:** Paula Aguirre <br>
#
# ----
# <div style="background-color:#fffff;">
#     <br>
#     <p style="text-align:center;font-family:Times New Roman;color:black;font-size:20pt;font-weight:bold;margin:20px">
#         Introducción a la Ciencia de Datos: Proyecto Final
#     </p>
#     <p style="text-align:center;font-family:Times New Roman;color:black;font-size:20pt;font-weight:bold;margin:20px">
#         Influencia de los factores sociales y económicos en la proyección de la
# delincuencia.
#     </p>
#     <p style="text-align:center;font-family:Times New Roman;color:black;font-size:12pt;font-weight:bold;margin:20px">
#         <br>Cristóbal Cancino - cristobal.cancinob@uc.cl</br>
#         <br>Diego Rodríguez - drodrguez@uc.cl</br>
#         <br>Benjamín Prieto - bprietz@uc.cl</br>
#         <br>Larry Uribe - larry@uc.cl</br>
#         <br>14 de diciembre de 2021
#         <br><br><b>Tiempo de ejecución aproximado:</b> 40 segundos.
#     </p>
#     <br><br>
# </div>

# %%
import pandas as pd
import requests 
import os
import io, zipfile

# %%
#Cargar archivos (I) : Data sobre denuncias de crimen de mayor connotación social.

link_denuncias = 'http://cead.spd.gov.cl/centro-de-documentacion/?wpdmpro=estadisticas-anuales-delitos-de-mayor-connotacion-social-dmcs-base-censo-2017&wpdmdl=3047&'
r = requests.get(link_denuncias, stream = True)
#Descompresión de zip
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
#El archivo a ocupar para los delitos lleva por nombre 'Frecuencia Anual_DENUNCIA'. 
path_denuncias = os.path.join('Data', 'Delitos', 'Frecuencia Anual_DENUNCIA.xlsx')
data_denuncias = pd.read_excel(path_denuncias, sheet_name = None)
columnas_denuncias = data_denuncias.keys()

# %%
for columna in columnas_denuncias:
    display(data_denuncias[columna].T.head())
# Out:
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0    407005.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                3845.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                      3813.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                          3810.0        3.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                             32.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    7.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                  112.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                              94.0       17.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               1.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                  386.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                            385.0               1.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE MAYOR CON...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                  243.0
#
# [5 rows x 424 columns]
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0     48937.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                 270.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                       270.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                           270.0        0.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              0.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    0.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    4.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                               1.0        3.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    9.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                              9.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                   12.0
#
# [5 rows x 424 columns]
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0     17165.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                 109.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                       109.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                           109.0        0.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              0.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    0.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    0.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                               0.0        0.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    0.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                              0.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS POR...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                    1.0
#
# [5 rows x 424 columns]
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0    158576.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                1382.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                      1369.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                          1366.0        3.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                             13.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    3.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                   15.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                              14.0        1.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                  103.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                            103.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                   90.0
#
# [5 rows x 424 columns]
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0     11486.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                 269.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                       269.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                           269.0        0.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              0.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    0.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    1.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                               1.0        0.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    3.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                              3.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                    2.0
#
# [5 rows x 424 columns]
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0     38661.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                 254.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                       252.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                           252.0        0.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              2.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    1.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    2.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                               2.0        0.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    5.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                              5.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                    0.0
#
# [5 rows x 424 columns]
#                                                                          0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                               NaN
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
#
#                                                     1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...  NaN     ORDEN           1
# Unnamed: 1                                          NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                          NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                          NaN       Año         NaN
# Unnamed: 4                                          NaN    2005.0     64972.0
#
#                                                                              4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                             2
# Unnamed: 1                                                                REGION
# Unnamed: 2                                          Región de Arica y Parinacota
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                 544.0
#
#                                                                    5    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                   3
# Unnamed: 1                                                   PROVINCIA
# Unnamed: 2                                          Provincia de Arica
# Unnamed: 3                                                         NaN
# Unnamed: 4                                                       538.0
#
#                                                        6          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       4          5
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                           Arica  Camarones
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                           537.0        1.0
#
#                                                                         8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                        6
# Unnamed: 1                                                        PROVINCIA
# Unnamed: 2                                          Provincia de Parinacota
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              6.0
#
#                                                               9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              7  ...
# Unnamed: 1                                                 COMUNA  ...
# Unnamed: 2                                          General Lagos  ...
# Unnamed: 3                                                    NaN  ...
# Unnamed: 4                                                    1.0  ...
#
#                                                                414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...             412
# Unnamed: 1                                                  COMUNA
# Unnamed: 2                                          Cabo de Hornos
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                                               415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            413
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Tierra del Fuego
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                    2.0
#
#                                                          416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       414        415
# Unnamed: 1                                            COMUNA     COMUNA
# Unnamed: 2                                          Porvenir  Primavera
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                               2.0        0.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                   35.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                             35.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE ROBOS CON...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# ...
# Unnamed: 3                                               NaN        NaN
# Unnamed: 4                                               6.0        1.0
#
#                                                          418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE LESIONES ...       416
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                          Timaukel
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                               419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE LESIONES ...                            417
# Unnamed: 1                                                              PROVINCIA
# Unnamed: 2                                          Provincia de Última Esperanza
# Unnamed: 3                                                                    NaN
# Unnamed: 4                                                                   56.0
#
#                                                         420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE LESIONES ...      418               419
# Unnamed: 1                                           COMUNA            COMUNA
# Unnamed: 2                                          Natales  Torres del Paine
# Unnamed: 3                                              NaN               NaN
# Unnamed: 4                                             56.0               0.0
#
#                                                                 422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE LESIONES ...              420
# Unnamed: 1                                                        -
# Unnamed: 2                                          Sin información
# Unnamed: 3                                                      NaN
# Unnamed: 4                                                      0.0
#
#                                                               423
# FRECUENCIA DE DENUNCIA POR DELITOS DE LESIONES ...            421
# Unnamed: 1                                                      -
# Unnamed: 2                                          No Especifica
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                    3.0
#
# [5 rows x 424 columns]
#                                                                         0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                              NaN
# Unnamed: 2                                                              NaN
# Unnamed: 3                                                              NaN
# Unnamed: 4                                                              NaN
#
#                                                    1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES  NaN     ORDEN           1
# Unnamed: 1                                         NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                         NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                         NaN       Año         NaN
# Unnamed: 4                                         NaN    2005.0      2455.0
#
#                                                                             4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES                             2
# Unnamed: 1                                                               REGION
# Unnamed: 2                                         Región de Arica y Parinacota
# Unnamed: 3                                                                  NaN
# Unnamed: 4                                                                 14.0
#
#                                                                   5       6    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES                   3       4
# Unnamed: 1                                                  PROVINCIA  COMUNA
# Unnamed: 2                                         Provincia de Arica   Arica
# Unnamed: 3                                                        NaN     NaN
# Unnamed: 4                                                       14.0    14.0
#
#                                                          7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES          5
# Unnamed: 1                                            COMUNA
# Unnamed: 2                                         Camarones
# Unnamed: 3                                               NaN
# Unnamed: 4                                               0.0
#
#                                                                        8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES                        6
# Unnamed: 1                                                       PROVINCIA
# Unnamed: 2                                         Provincia de Parinacota
# Unnamed: 3                                                             NaN
# Unnamed: 4                                                             0.0
#
#                                                              9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES              7  ...
# Unnamed: 1                                                COMUNA  ...
# Unnamed: 2                                         General Lagos  ...
# Unnamed: 3                                                   NaN  ...
# Unnamed: 4                                                   0.0  ...
#
#                                                               414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES             412
# Unnamed: 1                                                 COMUNA
# Unnamed: 2                                         Cabo de Hornos
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                    0.0
#
#                                                                              415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES                            413
# Unnamed: 1                                                             PROVINCIA
# Unnamed: 2                                         Provincia de Tierra del Fuego
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                   1.0
#
#                                                         416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES       414        415
# Unnamed: 1                                           COMUNA     COMUNA
# Unnamed: 2                                         Porvenir  Primavera
# Unnamed: 3                                              NaN        NaN
# Unnamed: 4                                              1.0        0.0
#
#                                                         418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES       416
# Unnamed: 1                                           COMUNA
# Unnamed: 2                                         Timaukel
# Unnamed: 3                                              NaN
# Unnamed: 4                                              0.0
#
#                                                                              419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES                            417
# Unnamed: 1                                                             PROVINCIA
# Unnamed: 2                                         Provincia de Última Esperanza
# Unnamed: 3                                                                   NaN
# Unnamed: 4                                                                   5.0
#
#                                                        420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES      418               419
# Unnamed: 1                                          COMUNA            COMUNA
# Unnamed: 2                                         Natales  Torres del Paine
# Unnamed: 3                                             NaN               NaN
# Unnamed: 4                                             5.0               0.0
#
#                                                                422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES              420
# Unnamed: 1                                                       -
# Unnamed: 2                                         Sin información
# Unnamed: 3                                                     NaN
# Unnamed: 4                                                     0.0
#
#                                                              423
# FRECUENCIA DE DENUNCIA POR DELITOS DE VIOLACIONES            421
# Unnamed: 1                                                     -
# Unnamed: 2                                         No Especifica
# Unnamed: 3                                                   NaN
# Unnamed: 4                                                  27.0
#
# [5 rows x 424 columns]
#                                                                        0    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS  SEGÚN UNIDAD TERRITORIAL
# Unnamed: 1                                                             NaN
# Unnamed: 2                                                             NaN
# Unnamed: 3                                                             NaN
# Unnamed: 4                                                             NaN
#
#                                                   1         2           3    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS  NaN     ORDEN           1
# Unnamed: 1                                        NaN  UN_ADMIN        PAÍS
# Unnamed: 2                                        NaN    UNIDAD  TOTAL PAÍS
# Unnamed: 3                                        NaN       Año         NaN
# Unnamed: 4                                        NaN    2005.0       300.0
#
#                                                                            4    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS                             2
# Unnamed: 1                                                              REGION
# Unnamed: 2                                        Región de Arica y Parinacota
# Unnamed: 3                                                                 NaN
# Unnamed: 4                                                                 0.0
#
#                                                                  5       6    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS                   3       4
# Unnamed: 1                                                 PROVINCIA  COMUNA
# Unnamed: 2                                        Provincia de Arica   Arica
# Unnamed: 3                                                       NaN     NaN
# Unnamed: 4                                                       0.0     0.0
#
#                                                         7    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS          5
# Unnamed: 1                                           COMUNA
# Unnamed: 2                                        Camarones
# Unnamed: 3                                              NaN
# Unnamed: 4                                              0.0
#
#                                                                       8    \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS                        6
# Unnamed: 1                                                      PROVINCIA
# Unnamed: 2                                        Provincia de Parinacota
# Unnamed: 3                                                            NaN
# Unnamed: 4                                                            0.0
#
#                                                             9    ...  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS              7  ...
# Unnamed: 1                                               COMUNA  ...
# Unnamed: 2                                        General Lagos  ...
# Unnamed: 3                                                  NaN  ...
# Unnamed: 4                                                  0.0  ...
#
#                                                              414  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS             412
# Unnamed: 1                                                COMUNA
# Unnamed: 2                                        Cabo de Hornos
# Unnamed: 3                                                   NaN
# Unnamed: 4                                                   0.0
#
#                                                                             415  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS                            413
# Unnamed: 1                                                            PROVINCIA
# Unnamed: 2                                        Provincia de Tierra del Fuego
# Unnamed: 3                                                                  NaN
# Unnamed: 4                                                                  1.0
#
#                                                        416        417  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS       414        415
# Unnamed: 1                                          COMUNA     COMUNA
# Unnamed: 2                                        Porvenir  Primavera
# Unnamed: 3                                             NaN        NaN
# Unnamed: 4                                             1.0        0.0
#
#                                                        418  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS       416
# Unnamed: 1                                          COMUNA
# Unnamed: 2                                        Timaukel
# Unnamed: 3                                             NaN
# Unnamed: 4                                             0.0
#
#                                                                             419  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS                            417
# Unnamed: 1                                                            PROVINCIA
# Unnamed: 2                                        Provincia de Última Esperanza
# Unnamed: 3                                                                  NaN
# Unnamed: 4                                                                  1.0
#
#                                                       420               421  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS      418               419
# Unnamed: 1                                         COMUNA            COMUNA
# Unnamed: 2                                        Natales  Torres del Paine
# Unnamed: 3                                            NaN               NaN
# Unnamed: 4                                            1.0               0.0
#
#                                                               422  \
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS              420
# Unnamed: 1                                                      -
# Unnamed: 2                                        Sin información
# Unnamed: 3                                                    NaN
# Unnamed: 4                                                    0.0
#
#                                                             423
# FRECUENCIA DE DENUNCIA POR DELITOS DE HOMICIDIOS            421
# Unnamed: 1                                                    -
# Unnamed: 2                                        No Especifica
# Unnamed: 3                                                  NaN
# Unnamed: 4                                                  1.0
#
# [5 rows x 424 columns]

# %%
# Cargar archivos (II) : Información varía sobre comunas.
link_info_comunal = "https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/Otros/InformacionComunas.csv"
r = requests.get(link_info_comunal, stream=True)
data_comunas = pd.read_csv(link_info_comunal)
data_comunas.head()
# Out:
#      Region  Codigo region         Comuna  Codigo comuna  Superficie_km2  \
# 0  Tarapacá              1        Iquique           1101         2289.53
# 1  Tarapacá              1  Alto Hospicio           1107          571.19
# 2  Tarapacá              1   Pozo Almonte           1401        13765.80
# 3  Tarapacá              1         Camiña           1402         2199.83
# 4  Tarapacá              1       Colchane           1403         4007.84
#
#    Poblacion
# 0   223463.0
# 1   129999.0
# 2    17395.0
# 3     1375.0
# 4     1583.0

# %%
# Cargar archivos (III) : Información plan paso a paso
link_pap = 'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/Paso_a_paso/paso_a_paso.csv'
r = requests.get(link_pap, stream = True)
data_pap = pd.read_csv(link_pap)
data_pap.head()
# Out:
#    codigo_region   region_residencia  codigo_comuna comuna_residencia    zona  \
# 0             15  Arica y Parinacota          15101             Arica   Rural
# 1             15  Arica y Parinacota          15101             Arica  Urbana
# 2             15  Arica y Parinacota          15102         Camarones   Total
# 3             15  Arica y Parinacota          15202     General Lagos   Total
# 4             15  Arica y Parinacota          15201             Putre   Total
#
#    2020-07-28  2020-07-29  2020-07-30  2020-07-31  2020-08-01  ...  \
# 0           3           3           3           3           3  ...
# 1           1           1           1           1           1  ...
# 2           3           3           3           3           3  ...
# 3           3           3           3           3           3  ...
# 4           3           3           3           3           3  ...
#
#    2021-11-15  2021-11-16  2021-11-17  2021-11-18  2021-11-19  2021-11-20  \
# 0           3           3           3           3           3           3
# 1           3           3           3           3           3           3
# 2           4           4           4           4           4           4
# 3           4           4           4           4           4           4
# 4           4           4           4           4           4           4
#
#    2021-11-21  2021-11-22  2021-11-23  2021-11-24
# 0           3           3           3           3
# 1           3           3           3           3
# 2           4           4           4           4
# 3           4           4           4           4
# 4           4           4           4           4
#
# [5 rows x 490 columns]

# %%
# Cargar archivos (IV) : Información sobre natalidad
# Obtendremos varios archivos que contienen información anual
links_natalidad = {2019:'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/RegistroCivil/Nacimientos/Nacimientos_2019-01-01_2019-12-31_DO.csv',
                  2020:'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/RegistroCivil/Nacimientos/Nacimientos_2020-01-01_2020-12-31_DO.csv',
                   2018:'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/RegistroCivil/Nacimientos/Nacimientos_2018-01-01_2018-12-31_DO.csv'}

datas_natalidad = dict()

for ano in range(2018, 2021):
    datas_natalidad[ano] = pd.read_csv(links_natalidad[ano])
    
datas_natalidad[2018]
# Out:
#              Region  Codigo region    Comuna  Codigo comuna  Nacimientos  \
# 0          Tarapacá              1   Iquique           1101           29
# 1          Tarapacá              1   Iquique           1101           29
# 2          Tarapacá              1   Iquique           1101           18
# 3          Tarapacá              1   Iquique           1101           18
# 4          Tarapacá              1   Iquique           1101           31
# ...             ...            ...       ...            ...          ...
# 19373  La Araucanía              9  Victoria           9211            2
# 19374  La Araucanía              9  Victoria           9211            7
# 19375  La Araucanía              9  Victoria           9211            6
# 19376  La Araucanía              9  Victoria           9211            7
# 19377  La Araucanía              9  Victoria           9211            6
#
#             Fecha
# 0      2018-01-02
# 1      2018-01-03
# 2      2018-01-04
# 3      2018-01-05
# 4      2018-01-08
# ...           ...
# 19373  2018-12-24
# 19374  2018-12-26
# 19375  2018-12-27
# 19376  2018-12-28
# 19377  2018-12-31
#
# [19378 rows x 6 columns]

# %%
#Cargar archivos (V) : Información sobre acceso a la salud
#Para medir el acceso a la salud solo se considerará la información actualizada al 2021, por el acceso a los datos;
#Y también por la poca variabilidad del nivel de hospitales

link_salud = 'https://repositoriodeis.minsal.cl/DatosAbiertos/Establecimientos_ChileDEIS_MINSAL%2029-10-2021.xlsx'
data_salud = pd.read_excel(link_salud, sheet_name = None)
data_salud = data_salud['Establecimientos V']

# %%
header_row = 1 
data_salud.columns = data_salud.iloc[header_row]
data_salud.head()
# Out:
# 1           26-216          126216      No Aplica           No Aplica  \
# 0  Código Antiguo   Código Vigente  Código  Madre  Código Nuevo Madre
# 1           26-216          126216      No Aplica           No Aplica
# 2           26-704          126704      No Aplica           No Aplica
# 3           26-204          126204      No Aplica           No Aplica
# 4           26-412          126412      No Aplica           No Aplica
#
# 1             12  Región De Magallanes y de la Antártica Chilena  \
# 0  Código Región                                   Nombre Región
# 1             12  Región De Magallanes y de la Antártica Chilena
# 2             12  Región De Magallanes y de la Antártica Chilena
# 3             12  Región De Magallanes y de la Antártica Chilena
# 4             12  Región De Magallanes y de la Antártica Chilena
#
# 1                                                 12  \
# 0  Código Dependencia Jerárquica (SEREMI / Servic...
# 1                                                 12
# 2                                                 26
# 3                                                 26
# 4                                                 26
#
# 1        SEREMI De Magallanes y la Antártica Chilena     No Perteneciente  \
# 0  Dependencia Jerárquica (SEREMI / Servicio de S...  Pertenencia al SNSS
# 1        SEREMI De Magallanes y la Antártica Chilena     No Perteneciente
# 2                       Servicio de Salud Magallanes        Perteneciente
# 3                       Servicio de Salud Magallanes        Perteneciente
# 4                       Servicio de Salud Magallanes        Perteneciente
#
# 1             Centro de Salud  ...                          NO  \
# 0        Tipo Establecimiento  ...  Tiene Servicio de Urgencia
# 1             Centro de Salud  ...                          NO
# 2                    Hospital  ...                          SI
# 3                    Hospital  ...                          SI
# 4  Posta de Salud Rural (PSR)  ...                          NO
#
# 1                    No Aplica     No Aplica                        -54.93672  \
# 0            Tipo de Urgencia   Tipo de SAPU  LATITUD      [Grados decimales]
# 1                    No Aplica     No Aplica                        -54.93672
# 2  Urgencia Hospitalaria (UEH)     No Aplica                       -54.935209
# 3  Urgencia Hospitalaria (UEH)     No Aplica                       -54.934374
# 4                    No Aplica     No Aplica                       -53.640546
#
# 1                    -67.61514                             Privado  \
# 0  LONGITUD [Grados decimales]  Tipo de Prestador Sistema de Salud
# 1                    -67.61514                             Privado
# 2                   -67.600393                            Público
# 3                   -67.608895                           Pendiente
# 4                   -69.645848                            Público
#
# 1     Vigente en operación       Baja Complejidad  \
# 0  Estado de Funcionamiento  Nivel de Complejidad
# 1     Vigente en operación       Baja Complejidad
# 2     Vigente en operación       Baja Complejidad
# 3     Vigente en operación    Mediana Complejidad
# 4     Vigente en operación       Baja Complejidad
#
# 1   Atención Abierta-Ambulatoria NaN
# 0         Modalidad de Atención  NaN
# 1   Atención Abierta-Ambulatoria NaN
# 2  Atención Cerrada-Hospitalaria NaN
# 3  Atención Cerrada-Hospitalaria NaN
# 4   Atención Abierta-Ambulatoria NaN
#
# [5 rows x 32 columns]

# %%
#Cargar archivos (VI): Información sobre la mortalidad.

links_mortalidad = {2019:'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/RegistroCivil/Defunciones/Defunciones_2019-01-01_2019-12-31_DO.csv',
                  2020:'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/RegistroCivil/Defunciones/Defunciones_2020-01-01_2020-12-31_DO.csv',
                   2018:'https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/input/RegistroCivil/Defunciones/Defunciones_2018-01-01_2018-12-31_DO.csv' }

datas_mortalidad = dict()

for ano in range(2018, 2021):
    datas_mortalidad[ano] = pd.read_csv(links_mortalidad[ano])

datas_mortalidad[2018]
# Out:
#              Region  Codigo region    Comuna  Codigo comuna  Defunciones  \
# 0          Tarapacá              1   Iquique           1101           11
# 1          Tarapacá              1   Iquique           1101            5
# 2          Tarapacá              1   Iquique           1101            5
# 3          Tarapacá              1   Iquique           1101            4
# 4          Tarapacá              1   Iquique           1101           11
# ...             ...            ...       ...            ...          ...
# 35566  La Araucanía              9  Victoria           9211            2
# 35567  La Araucanía              9  Victoria           9211            3
# 35568  La Araucanía              9  Victoria           9211            2
# 35569  La Araucanía              9  Victoria           9211            1
# 35570  La Araucanía              9  Victoria           9211            3
#
#             Fecha
# 0      2018-01-02
# 1      2018-01-03
# 2      2018-01-04
# 3      2018-01-05
# 4      2018-01-08
# ...           ...
# 35566  2018-12-21
# 35567  2018-12-24
# 35568  2018-12-26
# 35569  2018-12-28
# 35570  2018-12-31
#
# [35571 rows x 6 columns]

# %%
#ESTA PARTE ESTÁ INCOMPLETA. COMPLETAR EL 25-11.
linkazo = 'http://datos.mineduc.cl/datasets/196387-directorio-de-establecimientos-2021.download/'
#headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
          #'Cookie':'_ga=GA1.2.377815330.1633997856; _hjid=bfe9d992-da76-49cd-a7a3-6c82b7d655c7; fpestid=xtL6ZQONtwqONtIca9x4o2WAPNfqzeiJaYoZp7J0OmqM_eJwGYVkPPc_OE1nj86MiKnffA; __utmz=212104321.1634046891.2.2.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not provided); _gid=GA1.2.1117445521.1637702821; __utma=212104321.377815330.1633997856.1634310102.1637702823.5; __utmc=212104321; _hjSessionUser_667338=eyJpZCI6IjI2MGZiYzk0LTI2ZjItNTI5My05NDNiLTBhMjFlYTM2YWU1YiIsImNyZWF0ZWQiOjE2Mzc3MDI4MjEzNzAsImV4aXN0aW5nIjp0cnVlfQ==; _hjSession_667338=eyJpZCI6IjlkZTdkNDJmLTUyNTEtNGI2NS1iNmE0LWU5YmQwYzAzODA4YSIsImNyZWF0ZWQiOjE2Mzc3MDI4MjMxNzR9; _hjAbsoluteSessionInProgress=0; __utmt=1; __utmb=212104321.2.10.1637702823; _hjIncludedInPageviewSample=1'}
r = requests.get(linkazo)#, headers = headers)
print (r.status_code)

session = requests.Session()


ruta_b_educacion = os.path.join('Data', 'Educacion')
#Se necesita crear la carpeta para almacenar los archivos de datos.
#exist_ok permite evitar errores derivados de la ya-existencia de la carpeta.
os.makedirs(ruta_b_educacion, exist_ok = True)
# Out:
# 403

# %%
ruta_arch = os.path.join(ruta_b_educacion, 'Establecimientos_2021.csv')
with open(ruta_arch, 'wb') as establecimientos_2021:
    establecimientos_2021.write(r.content)
