# %%
import pandas as pd

# %%
data_1 = pd.read_excel(r'C:\Users\diego\OneDrive\Desktop\UC\2do semestre\Intro a la ciencia de datos\Grupo-8-CDD\Datos\Frecuencia Mensual_DENUNCIA.xlsx')

# %%
header = data_1.iloc[2].values
data_1 = data_1[3:]
data_1.columns = header
data_1
# Out:
#     ORDEN   UN_ADMIN                         UNIDAD Período Ene-2005 Feb-2005  \
# 3       1       PAÍS                     TOTAL PAÍS     NaN    33103    30881
# 4       2     REGION   Región de Arica y Parinacota     NaN      352      317
# 5       3  PROVINCIA             Provincia de Arica     NaN      352      314
# 6       4     COMUNA                          Arica     NaN      352      314
# 7       5     COMUNA                      Camarones     NaN        0        0
# ..    ...        ...                            ...     ...      ...      ...
# 419   417  PROVINCIA  Provincia de Última Esperanza     NaN       31       25
# 420   418     COMUNA                        Natales     NaN       31       25
# 421   419     COMUNA               Torres del Paine     NaN        0        0
# 422   420          -                Sin información     NaN        0        0
# 423   421          -                  No Especifica     NaN       31       55
#
# ...

# %%
data_1.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 3 to 423
# Data columns (total 202 columns):
#  #    Column    Dtype
# ---   ------    -----
#  0    ORDEN     object
#  1    UN_ADMIN  object
#  2    UNIDAD    object
#  3    Período   object
#  4    Ene-2005  object
#  5    Feb-2005  object
#  6    Mar-2005  object
#  7    Abr-2005  object
#  8    May-2005  object
#  9    Jun-2005  object
#  10   Jul-2005  object
#  11   Ago-2005  object
#  12   Sep-2005  object
#  13   Oct-2005  object
#  14   Nov-2005  object
#  15   Dic-2005  object
#  16   Ene-2006  object
#  17   Feb-2006  object
#  18   Mar-2006  object
#  19   Abr-2006  object
#  20   May-2006  object
#  21   Jun-2006  object
#  22   Jul-2006  object
#  23   Ago-2006  object
#  24   Sep-2006  object
#  25   Oct-2006  object
#  26   Nov-2006  object
#  27   Dic-2006  object
#  28   Ene-2007  object
#  29   Feb-2007  object
#  30   Mar-2007  object
#  31   Abr-2007  object
#  32   May-2007  object
# ...

# %%
data_2 = pd.read_csv(r'C:\Users\diego\OneDrive\Desktop\UC\2do semestre\Intro a la ciencia de datos\Grupo-8-CDD\Datos\paso_a_paso.csv')

# %%
data_2.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 448 columns):
#  #    Column             Dtype
# ---   ------             -----
#  0    codigo_region      int64
#  1    region_residencia  object
#  2    codigo_comuna      int64
#  3    comuna_residencia  object
#  4    zona               object
#  5    2020-07-28         int64
#  6    2020-07-29         int64
#  7    2020-07-30         int64
#  8    2020-07-31         int64
#  9    2020-08-01         int64
#  10   2020-08-02         int64
#  11   2020-08-03         int64
#  12   2020-08-04         int64
#  13   2020-08-05         int64
#  14   2020-08-06         int64
#  15   2020-08-07         int64
#  16   2020-08-08         int64
#  17   2020-08-09         int64
#  18   2020-08-10         int64
#  19   2020-08-11         int64
#  20   2020-08-12         int64
#  21   2020-08-13         int64
#  22   2020-08-14         int64
#  23   2020-08-15         int64
# ...

# %%
data_3 = pd.read_csv(r'C:\Users\diego\OneDrive\Desktop\UC\2do semestre\Intro a la ciencia de datos\Grupo-8-CDD\Datos\defunciones_2020.csv')

# %%
data_3.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17829 entries, 0 to 17828
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         17829 non-null  object
#  1   Codigo region  17829 non-null  int64
#  2   Comuna         17829 non-null  object
#  3   Codigo comuna  17829 non-null  int64
#  4   Defunciones    17829 non-null  int64
#  5   Fecha          17829 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 835.9+ KB

# %%
data_4 = pd.read_csv(r'C:\Users\diego\OneDrive\Desktop\UC\2do semestre\Intro a la ciencia de datos\Grupo-8-CDD\Datos\nacimientos_2021.csv')

# %%
data_4.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7893 entries, 0 to 7892
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         7893 non-null   object
#  1   Codigo region  7893 non-null   int64
#  2   Comuna         7893 non-null   object
#  3   Codigo comuna  7893 non-null   int64
#  4   Nacimientos    7893 non-null   int64
#  5   Fecha          7893 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 370.1+ KB

# %%
data_5 = pd.read_csv(r'C:\Users\diego\OneDrive\Desktop\UC\2do semestre\Intro a la ciencia de datos\Grupo-8-CDD\Datos\InformacionComunas.csv')

# %%
data_5.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          346 non-null    object
#  1   Codigo region   346 non-null    int64
#  2   Comuna          346 non-null    object
#  3   Codigo comuna   346 non-null    int64
#  4   Superficie_km2  346 non-null    float64
#  5   Poblacion       346 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 16.3+ KB

# %%
data_6 = pd.read_csv(r'C:\Users\diego\OneDrive\Desktop\UC\2do semestre\Intro a la ciencia de datos\Grupo-8-CDD\Datos\Establecimientos.csv', sep = ';')

# %%
data_6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3814 entries, 0 to 3813
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Región            3813 non-null   object
#  1   Número de Región  3813 non-null   object
#  2   Comuna            3813 non-null   object
#  3   Establecimiento   3813 non-null   object
#  4   Teléfono          2263 non-null   float64
#  5   Pertenecencia     3813 non-null   object
#  6   Dirección         2169 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 208.7+ KB
